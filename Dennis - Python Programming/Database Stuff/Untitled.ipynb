# %%
import pandas
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas
#
# ModuleNotFoundError: No module named 'pandas'

# %%
# !pip install pandas
# Out:
# ...
#   Using cached pandas-2.0.3-cp311-cp311-win_amd64.whl (10.6 MB)
# ...
#      ---------------------------------------- 0.0/502.3 kB ? eta -:--:--
#       --------------------------------------- 10.2/502.3 kB ? eta -:--:--
#      -- ---------------------------------- 30.7/502.3 kB 325.1 kB/s eta 0:00:02
#      -- ---------------------------------- 30.7/502.3 kB 325.1 kB/s eta 0:00:02
#      -- ---------------------------------- 30.7/502.3 kB 325.1 kB/s eta 0:00:02
#      -- ---------------------------------- 30.7/502.3 kB 325.1 kB/s eta 0:00:02
#      -- ---------------------------------- 30.7/502.3 kB 325.1 kB/s eta 0:00:02
#      --- --------------------------------- 41.0/502.3 kB 115.5 kB/s eta 0:00:04
#      ------ ------------------------------ 81.9/502.3 kB 208.4 kB/s eta 0:00:03
#      ------ ------------------------------ 92.2/502.3 kB 218.5 kB/s eta 0:00:02
#      -------- --------------------------- 112.6/502.3 kB 251.6 kB/s eta 0:00:02
# ...

# %%
import pandas as pd

# %%
customers_data = pd.read_csv("customers.txt")

# %%
customers_data
# Out:
#    100    Dennis Muthui   Panama  20
# 0  101    Python Muthui    Kenya  21
# 1  102      Python Java   Kiambu  19
# 2  103  Python Java PHP  Nairobi  22
# 3  104  Python Java PHP  Nairobi  23
# 4  105    Web Developer   Taveta  22

# %%
# !pip install matplotlib
# Out:
# ...
#      ---------------------------------------- 0.0/7.6 MB ? eta -:--:--
#      ---------------------------------------- 0.0/7.6 MB ? eta -:--:--
#      ---------------------------------------- 0.0/7.6 MB 435.7 kB/s eta 0:00:18
#      ---------------------------------------- 0.0/7.6 MB 435.7 kB/s eta 0:00:18
#      ---------------------------------------- 0.0/7.6 MB 435.7 kB/s eta 0:00:18
#      ---------------------------------------- 0.0/7.6 MB 435.7 kB/s eta 0:00:18
#      ---------------------------------------- 0.0/7.6 MB 435.7 kB/s eta 0:00:18
#      ---------------------------------------- 0.0/7.6 MB 108.9 kB/s eta 0:01:10
#      ---------------------------------------- 0.1/7.6 MB 155.6 kB/s eta 0:00:49
#      ---------------------------------------- 0.1/7.6 MB 199.1 kB/s eta 0:00:38
#      ---------------------------------------- 0.1/7.6 MB 201.3 kB/s eta 0:00:38
#       --------------------------------------- 0.1/7.6 MB 233.8 kB/s eta 0:00:33
# ...

# %%
# !pip install plotly
# Out:
# ...
#      ---------------------------------------- 0.0/15.5 MB ? eta -:--:--
#      ---------------------------------------- 0.0/15.5 MB 1.4 MB/s eta 0:00:12
#      ---------------------------------------- 0.1/15.5 MB 1.2 MB/s eta 0:00:14
#      ---------------------------------------- 0.1/15.5 MB 1.2 MB/s eta 0:00:13
#       --------------------------------------- 0.2/15.5 MB 1.4 MB/s eta 0:00:12
#       --------------------------------------- 0.3/15.5 MB 1.4 MB/s eta 0:00:12
#       --------------------------------------- 0.4/15.5 MB 1.4 MB/s eta 0:00:11
#      - -------------------------------------- 0.5/15.5 MB 1.6 MB/s eta 0:00:10
#      - -------------------------------------- 0.5/15.5 MB 1.5 MB/s eta 0:00:10
#      - -------------------------------------- 0.6/15.5 MB 1.5 MB/s eta 0:00:11
#      - -------------------------------------- 0.6/15.5 MB 1.4 MB/s eta 0:00:11
#      - -------------------------------------- 0.6/15.5 MB 1.4 MB/s eta 0:00:11
# ...
